# %%
gpu = !nvidia-smi -L
print(gpu)

# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install wget git python3 python3-venv libgl1 libglib2.0-0 bc

# %%
# !git clone https://github.com/ckti/stable-diffusion-webui

# %%
# !cd stable-diffusion-webui;git checkout runchange;git pull;./webui.sh
